# %%
import pandas as pd

# %%
giften = pd.read_csv("file:///Users/saro/Desktop/partijen.csv", sep = ";")

# %%
giften.naam_gever = giften.naam_gever.fillna(method='ffill')

# %%
giften2016 = giften[giften.tijdvak == "Subtotaal 2016"]

# %%
giften2016.head(200)
# Out:
#                                                  Partij  \
# 6     1. Volkspartij voor de Vrijheid en Democratie ...
# 11    1. Volkspartij voor de Vrijheid en Democratie ...
# 16    1. Volkspartij voor de Vrijheid en Democratie ...
# 21    1. Volkspartij voor de Vrijheid en Democratie ...
# 26    1. Volkspartij voor de Vrijheid en Democratie ...
# 33    1. Volkspartij voor de Vrijheid en Democratie ...
# 38    1. Volkspartij voor de Vrijheid en Democratie ...
# 45    1. Volkspartij voor de Vrijheid en Democratie ...
# 51    1. Volkspartij voor de Vrijheid en Democratie ...
# 59                       2. Partij van de Arbeid (PvdA)
# 63                       2. Partij van de Arbeid (PvdA)
# 67                       2. Partij van de Arbeid (PvdA)
# 80                       2. Partij van de Arbeid (PvdA)
# 87                       2. Partij van de Arbeid (PvdA)
# 91                       2. Partij van de Arbeid (PvdA)
# 98                       2. Partij van de Arbeid (PvdA)
# ...
